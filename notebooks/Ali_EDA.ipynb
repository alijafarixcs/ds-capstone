# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
SEED=448

# %%
df_book=pd.read_csv(f'..\\data\\books_data.csv')
df_rating=pd.read_csv('..\\data\\books_rating.csv')

df_book=df_book.rename(str.lower, axis='columns')
df_rating=df_rating.rename(str.lower, axis='columns')

df_book['title']=df_book['title'].apply(lambda x:str(x).lower().strip())
df_rating['title']=df_rating['title'].apply(lambda x:str(x).lower().strip())

# %%
print(len(df_book))
print(df_book.info())
print(df_book.describe())

# %%
print(len(df_rating))
print(df_rating.info())
print(df_rating.describe())

# %%
df = pd.merge(df_rating,df_book, on = 'title',how='outer')

# %%
df[:4]
# Out:
#            id                           title  price         user_id
# 0  1882931173  its only art if its well hung!    NaN   AVCGYZL8FQQTD  \
# 1  0826414346        dr. seuss: american icon    NaN  A30TK6U7DNS82R
# 2  0826414346        dr. seuss: american icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        dr. seuss: american icon    NaN  A2MVUWT453QH61
#
#                           profilename review/helpfulness  review/score
# 0               Jim of Oz "jim-of-oz"                7/7           4.0  \
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
#
#    review/time                                   review/summary
# 0    940636800           Nice collection of Julie Strain images  \
# 1   1095724800                                Really Enjoyed It
# 2   1078790400  Essential for every personal and Public Library
# ...

# %%
print(len(df))
print(df.info())
print(df.describe())
# Out:
# 3320453
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3320453 entries, 0 to 3320452
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   id                  object
#  1   title               object
#  2   price               float64
#  3   user_id             object
#  4   profilename         object
#  5   review/helpfulness  object
#  6   review/score        float64
#  7   review/time         int64
#  8   review/summary      object
#  9   review/text         object
#  10  description         object
#  11  authors             object
#  12  image               object
#  13  previewlink         object
#  14  publisher           object
#  15  publisheddate       object
#  16  infolink            object
#  17  categories          object
#  18  ratingscount        float64
# dtypes: float64(3), int64(1), object(15)
# memory usage: 481.3+ MB
# None
#                price  review/score   review/time  ratingscount
# ...

# %%
#df[:3].column

#df['column_name'] = pd.to_numeric(df['column_name'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# id                          0
# title                       0
# price                 2827729
# user_id                633195
# profilename            633319
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            465
# review/text                 8
# description            709246
# authors                445405
# image                  605348
# previewlink            381503
# publisher              861685
# publisheddate          405970
# infolink               381503
# categories             620703
# ratingscount          1485606
# dtype: int64

# %%
filtered_groups = df.sort_values(by=['description','price'],ascending=False).groupby('title')  # Filter groups with duplicates
single_repeated_row = filtered_groups.head(1) 
single_repeated_row
# Out:
#                  id                                              title  price
# 2618686  B000N78SAE              la misteriosa llama de la reina loana    NaN  \
# 2138966  1844073238  scaling urban environmental challenges: from l...  44.00
# 219172   1888998822  investment euphoria and money madness: the inn...  24.87
# 1778372  0814406203  the international handbook of convertible secu...    NaN
# 1343290  0789313502  moonage daydream: the life & times of ziggy st...    NaN
# ...             ...                                                ...    ...
# 3320298  B000I4X6Z4  the dirty pair ii: dangerous acquaintances (di...    NaN
# 3320324  0970045867                            the iscariot conspiracy    NaN
# 3320385  B000O00U1K                               the saint in england    NaN
# 3320391  1931449007    shecky's bar, club and lounge guide for chicago    NaN
# 3320429  0696011352  better homes and gardens casual entertaining c...    NaN
#
# ...

# %%
single_repeated_row=single_repeated_row.applymap(lambda x: x.lower() if type(x) is str else x)
single_repeated_row
# Out:
#                  id                                              title  price
# 2618686  b000n78sae              la misteriosa llama de la reina loana    NaN  \
# 2138966  1844073238  scaling urban environmental challenges: from l...  44.00
# 219172   1888998822  investment euphoria and money madness: the inn...  24.87
# 1778372  0814406203  the international handbook of convertible secu...    NaN
# 1343290  0789313502  moonage daydream: the life & times of ziggy st...    NaN
# ...             ...                                                ...    ...
# 3320298  b000i4x6z4  the dirty pair ii: dangerous acquaintances (di...    NaN
# 3320324  0970045867                            the iscariot conspiracy    NaN
# 3320385  b000o00u1k                               the saint in england    NaN
# 3320391  1931449007    shecky's bar, club and lounge guide for chicago    NaN
# 3320429  0696011352  better homes and gardens casual entertaining c...    NaN
#
# ...

# %%
df=pd.read_csv(f'..\\data\\book_review.csv', low_memory=False)
df_copy=df.copy()
df

# %%
df=df_copy
random.seed(SEED)
df= df.sample(frac=0.01, random_state=SEED) # 3 000 000
df.head(3)

# %%
single_repeated_row.to_csv(f'..\\data\\book_review_single.csv')

# %%
df_light=df[['title', 'price' ,'description', 'authors', 'publisher',
        'categories']]
df_light.to_csv(f'..\\data\\book_review_light.csv')
